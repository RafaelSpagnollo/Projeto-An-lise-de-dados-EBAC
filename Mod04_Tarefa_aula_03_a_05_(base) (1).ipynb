# %% [markdown]
# ## Exercício 1: Vestibular
#
# Considere que a os dados gerados na célula abaixo contêm o número de acertos de 100 alunos em um vestibular para um curso de exatas, divididas pelos respectivos assuntos. Considere que cada assunto possui um número de questões conforme a tabela abaixo:
#
# | assunto | número de questões |
# |:---:|:---:|
# | Matemática | 24 |
# | Português | 18 |
# | Geografia | 8 |
# | Inglês | 8 |
# | História | 8 |
# | Física | 12 |
# | Química | 12 |
#
# Usando os comandos de operações com DataFrames que você aprendeu na Aula 03, calcule:
#
# 1. (operações com escalar) Calcule o percentual de acerto dos alunos por assunto.
# 2. (operações entre *DataFrames) Calcule o total de acertos de cada aluno.
# 3. Calcule o porcentual geral de cada aluno.
# 4. Suponha que a nota de corte para a segunda fase seja 45. Quantos alunos tiveram nota maior que 45?

# %%
import pandas as pd
import numpy  as np

np.random.seed(42)
df_mat = pd.DataFrame(np.random.randint(24, size=(100, 1)), columns=['Qt_acertos'])

df_por = pd.DataFrame(np.random.randint(18, size=(100, 1)), columns=['Qt_acertos'])

df_geo = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_ing = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_his = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_fis = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos'])

df_qui = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos'])

# %%
# 1) Seu código aqui
# alterando os nomes das colunas para não dar overlap
df_mat = df_mat.rename(columns={'Qt_acertos': 'mat'})
df_por = df_por.rename(columns={'Qt_acertos': 'por'})
df_geo = df_geo.rename(columns={'Qt_acertos': 'geo'}) 
df_ing = df_ing.rename(columns={'Qt_acertos': 'ing'}) 
df_his = df_his.rename(columns={'Qt_acertos': 'his'}) 
df_fis = df_fis.rename(columns={'Qt_acertos': 'fis'}) 
df_qui = df_qui.rename(columns={'Qt_acertos': 'qui'})

#salvando as porcentagens de cada matéria em cada dataframe
df_mat_pctg = round(df_mat / 24 *100, 2)
df_por_pctg = round(df_por / 18 *100, 2)
df_geo_pctg = round(df_geo / 8 *100, 2)
df_ing_pctg = round(df_ing / 8 *100, 2)
df_his_pctg = round(df_his / 8 *100, 2)
df_fis_pctg = round(df_fis / 12 *100, 2)
df_qui_pctg = round(df_qui / 12 *100, 2)

#unificando o dataframe
df_pctgs = df_mat_pctg.join([df_por_pctg, df_geo_pctg, df_ing_pctg, df_his_pctg, df_fis_pctg, df_qui_pctg])
df_pctgs
# Out:
#       mat    por   geo   ing   his    fis    qui
# 0   25.00  38.89  87.5  37.5  12.5  66.67  25.00
# 1   79.17  55.56   0.0   0.0   0.0  91.67  66.67
# 2   58.33  88.89   0.0  62.5  87.5  33.33  33.33
# 3   41.67  38.89  37.5  50.0   0.0   0.00  66.67
# 4   29.17  11.11  25.0  87.5   0.0  75.00  25.00
# ..    ...    ...   ...   ...   ...    ...    ...
# 95  25.00  22.22  87.5  12.5  50.0  75.00  25.00
# 96  33.33   5.56  50.0  75.0  12.5  33.33  25.00
# 97  95.83  27.78   0.0  25.0  50.0   8.33  41.67
# 98   0.00  55.56  37.5  12.5  62.5  83.33  91.67
# 99  45.83  83.33   0.0  12.5  75.0  58.33  16.67
#
# [100 rows x 7 columns]

# %%
# 2) Seu código aqui

df_total_acertos = pd.DataFrame()
df_total_acertos['total acertos'] = df_mat.join([df_por, df_geo, df_ing, df_his, df_fis, df_qui]).T.sum()
df_total_acertos
# Out:
#     total acertos
# 0              35
# 1              48
# 2              50
# 3              32
# 4              30
# ..            ...
# 95             34
# 96             27
# 97             40
# 98             40
# 99             42
#
# [100 rows x 1 columns]

# %%
# 3) Seu código aqui

df_pctg_geral = pd.DataFrame()
df_pctg_geral['percentual geral'] = round(df_total_acertos / 90 * 100, 1)
df_pctg_geral
# Out:
#     percentual geral
# 0               38.9
# 1               53.3
# 2               55.6
# 3               35.6
# 4               33.3
# ..               ...
# 95              37.8
# 96              30.0
# 97              44.4
# 98              44.4
# 99              46.7
#
# [100 rows x 1 columns]

# %%
# 4) Seu código aqui
df_aprovados = df_total_acertos
df_aprovados['aprovado'] = 0
df_total_acertos.loc[df_total_acertos['total acertos'] >= 45, 'aprovado'] = 1
df_aprovados['aprovado'].sum()
# Out:
# 34

# %% [markdown]
# ## 2) Vestibular II
#
# Ainda sobre o mesmo banco de dados:
#
# 1. Neste vestibular, quem 'zera' em matemática, física ou química está desqualificado. Monte um novo *DataFrame* com os alunos desqualificados por este critério.
# 2. Quantos são esses alunos?
# 3. Qual a média desses alunos em história e geografia?
# 4. Monte um *DataFrame* com os alunos que passaram para a segunda fase. Repare que estes alunos não podem ter sido desqualificados.

# %%
# seu código aqui

# novo dataframe só com os desqualificados
df_desqualificados = df_pctgs.copy()
df_desqualificados['desqualificado'] = 0
df_desqualificados.loc[df_desqualificados['mat'] == 0, 'desqualificado'] = 1
df_desqualificados.loc[df_desqualificados['fis'] == 0, 'desqualificado'] = 1
df_desqualificados.loc[df_desqualificados['qui'] == 0, 'desqualificado'] = 1
df_desqualificados = df_desqualificados.loc[df_desqualificados['desqualificado'] == 1]
display(df_desqualificados)
# Out:
#       mat    por   geo   ing   his    fis    qui  desqualificado
# 3   41.67  38.89  37.5  50.0   0.0   0.00  66.67               1
# 6   25.00   0.00  87.5  87.5  62.5   0.00  33.33               1
# 10  41.67  44.44  37.5  25.0  12.5  58.33   0.00               1
# 12  83.33  44.44  37.5  87.5  12.5   0.00  25.00               1
# 14  29.17  61.11  12.5  87.5  12.5  33.33   0.00               1
# 20  95.83  61.11  75.0  62.5  75.0  16.67   0.00               1
# 25   0.00  22.22  87.5  50.0   0.0  33.33  66.67               1
# 26  45.83  77.78  75.0  25.0  87.5   0.00   0.00               1
# 27  87.50  72.22  12.5  62.5  87.5  25.00   0.00               1
# 33  58.33  44.44   0.0  62.5  75.0  50.00   0.00               1
# 35  45.83  77.78  75.0  37.5  37.5   0.00  91.67               1
# 49  33.33   5.56  12.5   0.0  12.5   0.00  66.67               1
# 56  29.17  33.33  87.5  62.5  75.0   0.00  66.67               1
# ...

# %%
# total de alunos desqualificados
alunos_desqualificados = df_desqualificados['desqualificado'].sum()
print(f'{alunos_desqualificados} alunos foram desqualificados por zerar em matemática, física ou química.')
# Out:
# 23 alunos foram desqualificados por zerar em matemática, física ou química.

# %%
# média em história e geografia dos alunos desqualificados 
print('Médias em história e geografia dos alunos desqualificados')
display(df_desqualificados[['his','geo']].mean())
# Out:
# Médias em história e geografia dos alunos desqualificados
# his    42.934783
# geo    40.217391
# dtype: float64

# %%
# dataframe só com os qualificados
df_qualificados = df_pctgs.copy()
df_qualificados['qualificado'] = 1
df_qualificados.loc[df_qualificados['mat'] == 0, 'qualificado'] = 0
df_qualificados.loc[df_qualificados['fis'] == 0, 'qualificado'] = 0
df_qualificados.loc[df_qualificados['qui'] == 0, 'qualificado'] = 0
df_qualificados = df_qualificados.loc[df_qualificados['qualificado'] == 1]
display(df_qualificados)
# Out:
#       mat    por   geo   ing   his    fis    qui  qualificado
# 0   25.00  38.89  87.5  37.5  12.5  66.67  25.00            1
# 1   79.17  55.56   0.0   0.0   0.0  91.67  66.67            1
# 2   58.33  88.89   0.0  62.5  87.5  33.33  33.33            1
# 4   29.17  11.11  25.0  87.5   0.0  75.00  25.00            1
# 5   83.33  11.11  62.5  37.5  25.0  75.00  75.00            1
# ..    ...    ...   ...   ...   ...    ...    ...          ...
# 93  50.00  88.89  62.5  62.5  75.0  50.00  50.00            1
# 95  25.00  22.22  87.5  12.5  50.0  75.00  25.00            1
# 96  33.33   5.56  50.0  75.0  12.5  33.33  25.00            1
# 97  95.83  27.78   0.0  25.0  50.0   8.33  41.67            1
# 99  45.83  83.33   0.0  12.5  75.0  58.33  16.67            1
#
# [77 rows x 8 columns]

# %% [markdown]
# ## 3) Vacinações no Acre
# Vamos trabalhar agora com a base de vacinações no Acre. Para facilitar a sua vida, copiamos o link do arquivo na célula abaixo.
#
# 1. Quantas vacinas estão registradas nessa base?
# 2. Quantos pacientes foram vacinados? (considere um paciente para cada valor único de ```paciente_id```)
# 3. Quantos pacientes únicos tomaram a primeira dose? OBS: Há um caractere especial neste campo. Receba os valores do campo com o método ```.unique()```.
# 4. Quantos pacientes com menos de 18 anos foram vacinados?
# 5. Quantos estabelecimentos aplicaram vacina no Acre?
#
#
# **OBS:** O portal do DATASUS pode apresentar instabilidades, retornando um erro na segunda célula abaixo. Por este motivo está disponível uma base estática, que se for baixada para o seu *working directory* pode ser lida com este comando: ```df = pd.read_csv('registros de vacinacao covid ACRE.csv', sep=';')```.
#
# **OBS2:** Para saber qual é o seu working directory, rode no jupyter: ```!pwd```.

# %%
arquivo = 'https://s3.sa-east-1.amazonaws.com/ckan.saude.gov.br/SIPNI/COVID/uf/uf%3DAC/part-00000-73052f20-f148-481d-baeb-19741d24badc.c000.csv'
df = pd.read_csv(arquivo, sep=';')
df.head()
# Out:
#                                  document_id  \
# 0  19b798e5-f139-41b6-8bf7-5039e1ba11f4-i0b0
# 1  bc230a77-3dca-4b92-bda6-5285805045fd-i0b0
# 2  664a629f-a54d-4c9f-94ee-2e99facf8adf-i0b0
# 3  bc314cf0-1ee0-423e-a13d-4c058ce4b9bb-i0b0
# 4  1eb1d07a-771e-4eaf-a338-55089fb2c15a-i0b0
#
#                                          paciente_id  paciente_idade  \
# 0  faeaa206e910b64df1df1f5863b8437be9ac3304aab104...              21
# 1  dd2bc9fb84a699061c85aee284cf8ce7bad949d1d18631...              45
# 2  e6562872f5a652f25bbecc335ca071d3da98561996b627...              81
# 3  b8fb6ba887cd182c12ae2643b3c705f0f3cb8e1b006389...              23
# 4  120895bb1e44770530c070d22b025b778eac6ac2ae28c9...              13
#
#   paciente_dataNascimento paciente_enumSexoBiologico  paciente_racaCor_codigo  \
# 0              2001-01-07                          M                        5
# 1              1976-07-18                          F                        1
# ...

# %%
# 1) Quantas vacinas estão registradas nessa base?

vacinas = df['paciente_id'].count()
print(f'Foram registradas {vacinas} vacinas nessa base')
# Out:
# Foram registradas 387095 vacinas nessa base

# %%
# 2) Quantos pacientes foram vacinados? (considere um paciente para cada valor único de paciente_id)

pacientes = df['paciente_id'].nunique()
print(f'{pacientes} pacientes foram vacinados')
# Out:
# 316461 pacientes foram vacinados

# %%
# 3) Quantos pacientes únicos tomaram a primeira dose? OBS: Há um caractere especial neste campo. Receba os valores do campo com o método .unique().

df['vacina_descricao_dose'].unique()
# Out:
# array(['Reforço', '2ª Dose', '1ª Dose', '2º Reforço', 'Única', 'Dose',
#        'Dose Adicional', '1º Reforço', '1ª Dose Revacinação', '3ª Dose',
#        'Revacinação', '3ª Dose Revacinação', '2ª Dose Revacinação',
#        '3º Reforço', '4ª Dose Revacinação', '5ª Dose Revacinação'],
#       dtype=object)

# %%
# 3) solução alternativa
df_primeira_dose = df[df['vacina_descricao_dose'].str.startswith('1ª Dose')]
df_primeira_dose['paciente_id'].nunique()
# Out:
# 143546

# %%
# 4) Quantos pacientes com menos de 18 anos foram vacinados?
pacientes_menores_18 = df.loc[df['paciente_idade'] < 18, 'paciente_id'].nunique()
print(f'Foram vacinados {pacientes_menores_18} pacientes com menos de 18 anos')
# Out:
# Foram vacinados 68208 pacientes com menos de 18 anos

# %%
# 5) Quantos estabelecimentos aplicaram vacina no Acre?
estabelecimentos = df['estabelecimento_valor'].nunique()
print(f'{estabelecimentos} estabelecimentos aplicaram vacinas no Acre')
# Out:
# 223 estabelecimentos aplicaram vacinas no Acre

# %% [markdown]
# ## 4) Vacinação II
# Gere um *DataFrame* que contenha somente os estabelecimentos que aplicaram vcinas a menores de 18 anos. Nesse *DataFrame* devem conter somente os dados dos estabelecimentos, mais uma coluna sendo a quantidade de vacinas que o estabelecimento aplicou a menores de 18 anos.
#
# 1. crie uma cópia do *DataFrame* original, contendo somente os registros de vacinas realizadas a menores de 18 anos.
# 2. crie uma lista das colunas desse *DataFrame* com o atributo de *DataFrame* **.columns()**
# 3. Nesse *DataFrame* faça uma contagem do campo ```vacina_categoria_nome```.
# 3. a partir da lista de colunas, escolha somente aquelas que são referentes ao estabelecimento, faça uma lista com esses valores.
# 4. usando o método *.loc*, selecione somente essas variáveis
# 5. Aplique o método **.drop_duplicates** e crie uma lista com uma linha para cada estabelecimento, com os dados do estabelecimento

# %%
# 1) crie uma cópia do DataFrame original, contendo somente os registros de vacinas realizadas a menores de 18 anos.
df_menores_18 = df.loc[df['paciente_idade'] < 18].copy()
df_menores_18
# Out:
#                                       document_id  \
# 4       1eb1d07a-771e-4eaf-a338-55089fb2c15a-i0b0
# 19      bcec46b4-9ce0-4f86-8c40-a96d72e10e9c-i0b0
# 20      19bfd2c3-410a-4592-a845-0226be0dff97-i0b0
# 22      7bcfa9ae-cafb-4923-9adb-495f5f51f680-i0b0
# 27      bd61f84d-90f4-4090-a79f-af3a5e8a62a9-i0b0
# ...                                           ...
# 387067  6eb6a5b4-684d-4d4d-9534-ec572697f78a-i0b0
# 387069  6eff5f3f-a890-472e-9100-8f4209e3b54e-i0b0
# 387070  6f25fa9f-92e3-48ae-b0a3-2a3b8d178947-i0b0
# 387072  6f5313fc-299d-44dc-ab84-1513d023b3c0-i0b0
# 387080  6fc96d56-fe04-43e8-972f-d3ac6f57b795-i0b0
#
#                                               paciente_id  paciente_idade  \
# 4       120895bb1e44770530c070d22b025b778eac6ac2ae28c9...              13
# 19      308a90cd0059b1f7574882616f2a352bd1823e6327d667...              14
# 20      e5dcc33f118d5e9d0caec3abdec5b515f8b943a3519acd...              11
# ...

# %%
# 2) crie uma lista das colunas desse DataFrame com o atributo de DataFrame .columns()
df_menores_18 = df_menores_18.rename(columns={'estalecimento_noFantasia': 'estabelecimento_noFantasia'})
lista_colunas = list(df_menores_18.columns)
lista_colunas
# Out:
# ['document_id',
#  'paciente_id',
#  'paciente_idade',
#  'paciente_dataNascimento',
#  'paciente_enumSexoBiologico',
#  'paciente_racaCor_codigo',
#  'paciente_racaCor_valor',
#  'paciente_endereco_coIbgeMunicipio',
#  'paciente_endereco_coPais',
#  'paciente_endereco_nmMunicipio',
#  'paciente_endereco_nmPais',
#  'paciente_endereco_uf',
#  'paciente_endereco_cep',
#  'paciente_nacionalidade_enumNacionalidade',
#  'estabelecimento_valor',
#  'estabelecimento_razaoSocial',
#  'estabelecimento_noFantasia',
#  'estabelecimento_municipio_codigo',
#  'estabelecimento_municipio_nome',
#  'estabelecimento_uf',
#  'vacina_grupoAtendimento_codigo',
#  'vacina_grupoAtendimento_nome',
#  'vacina_categoria_codigo',
#  'vacina_categoria_nome',
#  'vacina_lote',
#  'vacina_fabricante_nome',
#  'vacina_fabricante_referencia',
#  'vacina_dataAplicacao',
#  'vacina_descricao_dose',
#  'vacina_codigo',
#  'vacina_nome',
#  'sistema_origem']

# %%
# 3) Nesse DataFrame faça uma contagem do campo vacina_categoria_nome.
contagem = df_menores_18['vacina_categoria_nome'].count()
contagem_unicos = df_menores_18['vacina_categoria_nome'].nunique()

print(f'{contagem} valores no campo vacina_categoria_nome, sendo {contagem_unicos} valores únicos')
# Out:
# 57168 valores no campo vacina_categoria_nome, sendo 13 valores únicos

# %%
# 4) a partir da lista de colunas, escolha somente aquelas que são referentes ao estabelecimento, faça uma lista com esses valores.
lista_colunas_estabelecimento = pd.Series(lista_colunas)
lista_colunas_estabelecimento = lista_colunas_estabelecimento[lista_colunas_estabelecimento.str.startswith('estabelecimento')]
        
lista_colunas_estabelecimento
# Out:
# 14               estabelecimento_valor
# 15         estabelecimento_razaoSocial
# 16          estabelecimento_noFantasia
# 17    estabelecimento_municipio_codigo
# 18      estabelecimento_municipio_nome
# 19                  estabelecimento_uf
# dtype: object

# %%
# 5) usando o método .loc, selecione somente essas variáveis
df_estabelecimento = df_menores_18.loc[:,lista_colunas_estabelecimento]
df_estabelecimento
# Out:
#         estabelecimento_valor               estabelecimento_razaoSocial  \
# 4                     2000660  PREFEITURA MUNICIPAL DE SENADOR GUIOMARD
# 19                    6917291        PREFEITURA MUNICIPAL DE RIO BRANCO
# 20                    2000660  PREFEITURA MUNICIPAL DE SENADOR GUIOMARD
# 22                    7436440      PREFEITURA MUNICIPAL DE ASSIS BRASIL
# 27                    3544915             PREFEITURA MUNICIPAL DE FEIJO
# ...                       ...                                       ...
# 387067                6917291        PREFEITURA MUNICIPAL DE RIO BRANCO
# 387069                3810771          PREFEITURA MUNICIPAL DE TARAUACA
# 387070                6917291        PREFEITURA MUNICIPAL DE RIO BRANCO
# 387072                2002132         PREFEITURA MUN DE MAL THAUMATURGO
# 387080                6917291        PREFEITURA MUNICIPAL DE RIO BRANCO
#
#                                estabelecimento_noFantasia  \
# ...

# %%
# 6) Aplique o método .drop_duplicates e crie uma lista com uma linha para cada estabelecimento, com os dados do estabelecimento
df_estabelecimento.drop_duplicates()
# Out:
#         estabelecimento_valor                 estabelecimento_razaoSocial  \
# 4                     2000660    PREFEITURA MUNICIPAL DE SENADOR GUIOMARD
# 19                    6917291          PREFEITURA MUNICIPAL DE RIO BRANCO
# 22                    7436440        PREFEITURA MUNICIPAL DE ASSIS BRASIL
# 27                    3544915               PREFEITURA MUNICIPAL DE FEIJO
# 33                    2002922               SECRETARIA MUNICIPAL DE SAUDE
# ...                       ...                                         ...
# 170951                 197599          CENTRAL MUNICIPAL DE REDE DE FRIOS
# 183325                5493455   PREFEITURA MUNICIPAL DE PLACIDO DE CASTRO
# 194165                2001357  SECRETARIA MUNICIPAL DE SAUDE DE BRASILEIA
# 302673                 755605                          USF BARRO VERMELHO
# 381310                7565089          PREFEITURA MUNICIPAL DE RIO BRANCO
#
#                                estabelecimento_noFantasia  \
# ...
